# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8s.pt')

# Train the model
# !yolo task=detect mode=train model=yolov8s.pt data='/content/drive/My Drive/Assignment5/data.yaml' epochs=30
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image
Image('/content/runs/detect/train11/val_batch0_pred.jpg')

# %%
Image('/content/runs/detect/train11/confusion_matrix.png')

# %%
#Another way of train the dataset
results = model.train(data='/content/drive/My Drive/Assignment5/data.yaml', epochs=30, imgsz=800)
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image('/content/runs/detect/train12/val_batch0_pred.jpg')

# %%
Image('/content/runs/detect/train12/confusion_matrix.png')
